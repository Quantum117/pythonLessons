# %%
import pandas as pd
import numpy as np
import _sqlite3

# %%
with _sqlite3.connect('chinook.db') as conn:
    df = pd.read_sql('SELECT * from customers', conn)
    print(df.head(10))
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
# Task2

df2 = pd.read_json('iris.json')
# Display shape (rows, columns)
print("Shape of the dataset:", df2.shape)

# Display column names
print("Column names:", df2.columns.tolist())
# Out:
# Shape of the dataset: (150, 5)
# Column names: ['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species']

# %%
# Task3
df3 = pd.read_excel('titanic.xlsx')
print(df3.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#4
df = pd.read_parquet('flights')
df.info
# Out:
# <bound method DataFrame.info of          Year Quarter Month DayofMonth DayOfWeek  FlightDate  \
# 0        2022       2     4         15         5  2022-04-15
# 1        2022       2     4         16         6  2022-04-16
# 2        2022       2     4         17         7  2022-04-17
# 3        2022       2     4         18         1  2022-04-18
# 4        2022       2     4         19         2  2022-04-19
# ...       ...     ...   ...        ...       ...         ...
# 6729120  2022       3     7         12         2  2022-07-12
# 6729121  2022       3     7         13         3  2022-07-13
# 6729122  2022       3     7         14         4  2022-07-14
# 6729123  2022       3     7         15         5  2022-07-15
# 6729124  2022       3     7         16         6  2022-07-16
#
#         Reporting_Airline DOT_ID_Reporting_Airline  \
# 0                      OH                    20397
# 1                      OH                    20397
# ...

# %%
#5
df5 = pd.read_csv('movie.csv')
df5
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# Part 2: Exploring DataFrames

df = pd.read_json('iris.json')
df.columns =[columns.lower() for  columns in df.columns ]
df.loc[:, df.columns[:2]]
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
# titanic.xlsx
# So we give list of boolean numbers count to rows of df
df2 = pd.read_excel('titanic.xlsx')
males = df2.loc[(df2['Age']>30) & (df2['Sex'] == 'male')]
females = df2.loc[(df2['Age']>30) & (df2['Sex'] == 'female')]
males, females
# Out:
# (     PassengerId  Survived  Pclass                                  Name  \
#  4              5         0       3              Allen, Mr. William Henry
#  6              7         0       1               McCarthy, Mr. Timothy J
#  13            14         0       3           Andersson, Mr. Anders Johan
#  20            21         0       2                  Fynney, Mr. Joseph J
#  21            22         1       2                 Beesley, Mr. Lawrence
#  ..           ...       ...     ...                                   ...
#  867          868         0       1  Roebling, Mr. Washington Augustus II
#  872          873         0       1              Carlsson, Mr. Frans Olof
#  873          874         0       3           Vander Cruyssen, Mr. Victor
#  881          882         0       3                    Markun, Mr. Johann
#  890          891         0       3                   Dooley, Mr. Patrick
#
#        Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %% [markdown]
# From the Flights parquet file:
#
# Extract and print only the origin, dest, and carrier columns.
# Find the number of unique destinations.

# %%
import pandas as pd
df = pd.read_parquet('flights')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_parquet('flights')
#
# File ~\PycharmProjects\pythonLessons\.venv\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
import gc

# Run garbage collection
gc.collect()
# Out:
# 0

# %%
df[['Origin', 'Dest', 'CarrierDelay']]
# Out:
#         Origin Dest CarrierDelay
# 0          MDT  CLT         None
# 1          MDT  CLT         None
# 2          MDT  CLT         None
# 3          MDT  CLT         None
# 4          MDT  CLT         None
# ...        ...  ...          ...
# 6729120    BOS  ATL         None
# 6729121    BOS  ATL         None
# 6729122    BOS  ATL         None
# 6729123    BOS  ATL        17.00
# 6729124    BOS  ATL         None
#
# [6729125 rows x 3 columns]

# %% [markdown]
# From the movie.csv file:
# Filter rows where duration is greater than 120 minutes.
#
# Sort the filtered DataFrame by director_facebook_likes in descending order.

# %%
df4 = pd.read_csv('movie.csv')
df_4_2 = df4.loc[df4['duration']>120]

# Sorting by director_facebook_likes in descending order
sorted_df = df_4_2.sort_values(by='director_facebook_likes', ascending = False)
print(sorted_df)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 120   Color  Christopher Nolan                   478.0     128.0
# 66    Color  Christopher Nolan                   645.0     152.0
# 96    Color  Christopher Nolan                   712.0     169.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 97    Color  Christopher Nolan                   642.0     148.0
# ...     ...                ...                     ...       ...
# 3357  Color                NaN                     9.0     142.0
# 3582  Color                NaN                    10.0     240.0
# 3799  Color                NaN                     2.0     199.0
# 4005  Color                NaN                     NaN     197.0
# 4031  Color                NaN                    10.0     173.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 120                   22000.0                 11000.0       Liam Neeson
# ...

# %% [markdown]
# From iris.json: Calculate the mean, median, and standard deviation for each numerical column.

# %%
#Part3 filtering tasks
df = pd.read_json('iris.json')
# get columns as a list
column_names = [item for item in df.columns if item !='species']
df.loc[:, column_names].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Part3 filtering tasks
# ----> 2 df = pd.read_json('iris.json')
#       3 # get columns as a list
#       4 column_names = [item for item in df.columns if item !='species']
#
# NameError: name 'pd' is not defined

# %% [markdown]
# From titanic.xlsx: Find the minimum, maximum, and sum of passenger ages.

# %%
import pandas as pd
df_titanic = pd.read_excel('titanic.xlsx')
min_age = df_titanic.loc[5, ['Age']]
# Out:
# Age    NaN
# Name: 5, dtype: object

# %% [markdown]
# From movie.csv:
#
# Identify the director with the highest total director_facebook_likes.
# Find the 5 longest movies and their respective directors.

# %% [markdown]
# From Flights parquet file:
#
# Check for missing values in the dataset. Fill missing values in a numerical column with the column’s mean.
